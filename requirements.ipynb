# %% [markdown]
# <a href="https://colab.research.google.com/github/defnethecoder/DSA210-PROJECT/blob/main/requirements.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data Processing
pandas
numpy

# Visualization
matplotlib
seaborn

# Statistics (T-Test, ANOVA)
scipy

# Machine Learning (ML)
scikit-learn

# Feature Engineering
holidays

# JSON Data Processing
ast


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import json
import ast
import os
import warnings
import zipfile as zipfile
